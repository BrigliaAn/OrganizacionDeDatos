# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib notebook

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
p08 = pd.read_csv("../../home/lucas/Descargas/properati-AR-2017-08-01-properties-rent-six_months.csv",\
                  infer_datetime_format=True)

# %%
#Miramos un poco que datos tenemos y procedemos a limpiarlos
p08.head(3)
# Out:
#                                          id  created_on operation  \
# 0  57df5f7e24ecc7231a698adcefbdbba413e08901  2017-02-01      rent
# 1  b7d96e89c2effc24d3659bf4f01405586724758b  2017-02-01      rent
# 2  48f63c9a441b5a66343abbae885a97d50ca8cb49  2017-02-01      rent
#
#   property_type         place_name  \
# 0     apartment            Rosario
# 1            PH          Temperley
# 2         house  General Rodríguez
#
#                              place_with_parent_names country_name  \
# 0                       |Argentina|Santa Fe|Rosario|    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...    Argentina
# 2  |Argentina|Bs.As. G.B.A. Zona Oeste|General Ro...    Argentina
#
#                  state_name  geonames_id                        lat-lon  \
# 0                  Santa Fe    3838574.0        -32.9494718,-60.6316587
# 1    Bs.As. G.B.A. Zona Sur    3427776.0  -34.7676473285,-58.3859923587
# 2  Bs.As. G.B.A. Zona Oeste    3433780.0  -34.6501160392,-58.9660339715
#
#                          ...                          surface_covered_in_m2  \
# 0                        ...                                            NaN
# 1                        ...                                            4.0
# 2                        ...                                          304.0
#
#    price_usd_per_m2  price_per_m2 floor  rooms  expenses  \
# 0               NaN           NaN   NaN    NaN       NaN
# 1               NaN   1500.000000   NaN    NaN       NaN
# 2          6.051118    107.894737   NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15boi_alquiler_dep...
# 1  http://www.properati.com.ar/15boj_alquiler_ph_...
# 2  http://www.properati.com.ar/15bri_alquiler_cas...
#
#                                          description  \
# 0  EXCELENTE DEPARTAMENTO DE 2 DORMITORIOS, PISO ...
# 1  BUEN PH EN ALQUILER EN TEMPERLEY ESTE. o 15440...
# 2  CASA EN ALQUILER ANUAL  CON OPCION A COMPRA- A...
#
#                                                title  \
# 0               J.M. DE ROSAS 929 - 2 DORMITORIOS
# 1  BUEN PH , 3 ambientes ,EN ALQUILER en TEMPERLE...
# 2  CASA ALQUILER ANUAL- EL NACIONAL, GRAL. RODRIGUEZ
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/6/qX-hlMZ1XwGXI5...
# 1  https://thumbs4.properati.com/4/RDuQelGI1qnJmT...
# 2  https://thumbs4.properati.com/2/PPXbmserGHUVdC...
#
# [3 rows x 27 columns]

# %%
p08.dtypes
# Out:
# id                             object
# created_on                     object
# operation                      object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# description                    object
# title                          object
# image_thumbnail                object
# dtype: object

# %%
#Vemos un poco los tipos de datos que hay
p08['created_on'] = p08['created_on'].apply(pd.to_datetime)

# %%
p08.dtypes
p08.head(2)
# Out:
#                                          id created_on operation  \
# 0  57df5f7e24ecc7231a698adcefbdbba413e08901 2017-02-01      rent
# 1  b7d96e89c2effc24d3659bf4f01405586724758b 2017-02-01      rent
#
#   property_type place_name                            place_with_parent_names  \
# 0     apartment    Rosario                       |Argentina|Santa Fe|Rosario|
# 1            PH  Temperley  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...
#
#   country_name              state_name  geonames_id  \
# 0    Argentina                Santa Fe    3838574.0
# 1    Argentina  Bs.As. G.B.A. Zona Sur    3427776.0
#
#                          lat-lon  \
# 0        -32.9494718,-60.6316587
# 1  -34.7676473285,-58.3859923587
#
#                          ...                          surface_covered_in_m2  \
# 0                        ...                                            NaN
# 1                        ...                                            4.0
#
#    price_usd_per_m2  price_per_m2 floor  rooms  expenses  \
# 0               NaN           NaN   NaN    NaN       NaN
# 1               NaN        1500.0   NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15boi_alquiler_dep...
# 1  http://www.properati.com.ar/15boj_alquiler_ph_...
#
#                                          description  \
# 0  EXCELENTE DEPARTAMENTO DE 2 DORMITORIOS, PISO ...
# 1  BUEN PH EN ALQUILER EN TEMPERLEY ESTE. o 15440...
#
#                                                title  \
# 0               J.M. DE ROSAS 929 - 2 DORMITORIOS
# 1  BUEN PH , 3 ambientes ,EN ALQUILER en TEMPERLE...
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/6/qX-hlMZ1XwGXI5...
# 1  https://thumbs4.properati.com/4/RDuQelGI1qnJmT...
#
# [2 rows x 27 columns]

# %%
#Vemos los tipos de operaciones disponibles
p08.groupby('operation')
#Sólo tenemos operaciones del tipo 'rent'
# Out:
#               id  created_on  property_type  place_name  \
# operation
# rent       18492       18492          18492       18488
#
#            place_with_parent_names  country_name  state_name  geonames_id  \
# operation
# rent                         18492         18492       18492        15500
#
#            lat-lon    lat       ...         surface_covered_in_m2  \
# operation                       ...
# rent         11760  11760       ...                         14106
#
#            price_usd_per_m2  price_per_m2  floor  rooms  expenses  \
# operation
# rent                  10207         12954   1338   6328      3374
#
#            properati_url  description  title  image_thumbnail
# operation
# rent               18492        18491  18492            18138
#
# [1 rows x 26 columns]

# %%
#Miramos el archivo sell de agosto
ps208 = pd.read_csv('../../home/lucas/Descargas/properati-AR-2017-08-01-properties-sell.csv')
ps208.head(2)
# Out:
#                                          id  created_on operation  \
# 0  c8a66ee9e3da083ab66dacd165e8a5cc718b1cf2  2012-09-19      sell
# 1  a205c53378e7879cf7519659317fb410c060d20e  2012-10-22      sell
#
#   property_type            place_name  \
# 0         house  San Antonio De Padua
# 1         house  San Antonio De Padua
#
#                              place_with_parent_names country_name  \
# 0  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
# 1  |Argentina|Bs.As. G.B.A. Zona Oeste|Merlo|San ...    Argentina
#
#                  state_name  geonames_id lat-lon  \
# 0  Bs.As. G.B.A. Zona Oeste    3429244.0     NaN
# 1  Bs.As. G.B.A. Zona Oeste    3429244.0     NaN
#
#                          ...                          surface_covered_in_m2  \
# 0                        ...                                           93.0
# 1                        ...                                          220.0
#
#    price_usd_per_m2  price_per_m2 floor  rooms  expenses  \
# 0         360.36036   1290.322581   NaN    NaN       NaN
# 1        1000.00000   1000.000000   NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/udh_venta_casa_mer...
# 1  http://www.properati.com.ar/20hi_venta_casa_me...
#
#                                          description          title  \
# 0  CASA CON LOCAL EN VENTA EN PADUA.2 DORMITORIOS...  CASA EN VENTA
# 1  CHALET VENTA 4 AMBIENTES PADUA.EXCELENTE CHALE...  CASA EN VENTA
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/1/ufoyqwscVk8n3e...
# 1  https://thumbs4.properati.com/5/I5RS_jAIUseo9H...
#
# [2 rows x 27 columns]

# %%
ps208.count()
# Out:
# id                            187482
# created_on                    187482
# operation                     187482
# property_type                 187482
# place_name                    187447
# place_with_parent_names       187482
# country_name                  187482
# state_name                    187482
# geonames_id                   158318
# lat-lon                       118761
# lat                           118761
# lon                           118761
# price                         154443
# currency                      154441
# price_aprox_local_currency    154443
# price_aprox_usd               154443
# surface_total_in_m2           125027
# surface_covered_in_m2         152420
# price_usd_per_m2              105024
# price_per_m2                  131665
# floor                          14294
# rooms                          80320
# expenses                       17520
# properati_url                 187482
# description                   187473
# title                         187482
# image_thumbnail               182814
# dtype: int64

# %%
#Buscamos en otros archivos a ver si existen otro tipo de operaciones
ps08 = pd.read_csv('../../home/lucas/Descargas/properati-AR-2017-08-01-properties-sell-six_months.csv')

# %%
ps08.head(3)
# Out:
#                                          id  created_on operation  \
# 0  ad916bad59cdaf3c24c2d594547aa6067c4d6289  2017-02-01      sell
# 1  0de2ae882e1708c2941a672402f772ec83a92827  2017-02-01      sell
# 2  61cb773b63b911ad2ea5c823187d7ba1c7f3cadf  2017-02-01      sell
#
#   property_type place_name                      place_with_parent_names  \
# 0            PH  Mataderos        |Argentina|Capital Federal|Mataderos|
# 1     apartment   La Plata  |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|
# 2     apartment  Mataderos        |Argentina|Capital Federal|Mataderos|
#
#   country_name              state_name  geonames_id                  lat-lon  \
# 0    Argentina         Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1    Argentina  Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2    Argentina         Capital Federal    3430787.0  -34.6522615,-58.5229825
#
#                          ...                          surface_covered_in_m2  \
# 0                        ...                                           40.0
# 1                        ...                                            NaN
# 2                        ...                                           55.0
#
#    price_usd_per_m2  price_per_m2 floor  rooms  expenses  \
# 0       1127.272727   1550.000000   NaN    NaN       NaN
# 1               NaN           NaN   NaN    NaN       NaN
# 2       1309.090909   1309.090909   NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1  http://www.properati.com.ar/15bob_venta_depart...
# 2  http://www.properati.com.ar/15bod_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...
#
# [3 rows x 27 columns]

# %%
ps08.dtypes
# Out:
# id                             object
# created_on                     object
# operation                      object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# description                    object
# title                          object
# image_thumbnail                object
# dtype: object

# %%
#Vemos que tipo de operaciones tienen
print("cantidad de registro:"+str(ps08.count()['id']))
print("cantidad de operaciones: "+str(ps08.groupby('operation').count()['id']))
#Las operaciones son todas sell y coinciden con la cantidad de registros
# Out:
# cantidad de registro:121220
# cantidad de operaciones: operation
# sell    121220
# Name: id, dtype: int64

# %%
#Transformamos las fechas
ps08['created_on'] = ps08['created_on'].apply(pd.to_datetime)

# %%
ps08.head(2)
ps08.dtypes
# Out:
# id                                    object
# created_on                    datetime64[ns]
# operation                             object
# property_type                         object
# place_name                            object
# place_with_parent_names               object
# country_name                          object
# state_name                            object
# geonames_id                          float64
# lat-lon                               object
# lat                                  float64
# lon                                  float64
# price                                float64
# currency                              object
# price_aprox_local_currency           float64
# price_aprox_usd                      float64
# surface_total_in_m2                  float64
# surface_covered_in_m2                float64
# price_usd_per_m2                     float64
# price_per_m2                         float64
# floor                                float64
# rooms                                float64
# expenses                             float64
# properati_url                         object
# description                           object
# title                                 object
# image_thumbnail                       object
# dtype: object

# %%
#Como este archivo corresponde a agosto limpiamos los registros correspondientes a otros meses
ps08 = ps08[(ps08['created_on'] >= '2017-08-01') & (ps08['created_on'] <= '2017-08-31')]
ps08.head(5)
# Out:
#                                               id created_on operation  \
# 120867  0582b4e7b99b299008b2502ee7d134cbbff99aea 2017-08-01      sell
# 120868  376987444d049f2fdb33b0d984a7331686d7a9a7 2017-08-01      sell
# 120869  ed24015ec0dc382a8ec233b3340988e888593f9f 2017-08-01      sell
# 120870  b8e58f31cbb01828e583e0f47413d8701424e980 2017-08-01      sell
# 120871  ca5bec2573400220c2bd7690d85a85506c56308e 2017-08-01      sell
#
#        property_type    place_name  \
# 120867     apartment     Caballito
# 120868     apartment     Caballito
# 120869     apartment     Caballito
# 120870     apartment  Palermo Soho
# 120871     apartment  Palermo Soho
#
#                                  place_with_parent_names country_name  \
# 120867             |Argentina|Capital Federal|Caballito|    Argentina
# 120868             |Argentina|Capital Federal|Caballito|    Argentina
# 120869             |Argentina|Capital Federal|Caballito|    Argentina
# 120870  |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 120871  |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
#
#              state_name  geonames_id lat-lon  \
# 120867  Capital Federal    3435874.0     NaN
# 120868  Capital Federal    3435874.0     NaN
# 120869  Capital Federal    3435874.0     NaN
# 120870  Capital Federal    3430234.0     NaN
# 120871  Capital Federal    3430234.0     NaN
#
#                               ...                          \
# 120867                        ...
# 120868                        ...
# 120869                        ...
# 120870                        ...
# 120871                        ...
#
#         surface_covered_in_m2  price_usd_per_m2  price_per_m2 floor  rooms  \
# 120867                  160.0               NaN           NaN   NaN    NaN
# 120868                   56.0               NaN           NaN   NaN    NaN
# 120869                  142.0               NaN           NaN   NaN    NaN
# 120870                   34.0               NaN           NaN   NaN    NaN
# 120871                   50.0               NaN           NaN   NaN    NaN
#
#         expenses                                      properati_url  \
# 120867       NaN  http://www.properati.com.ar/1cig5_venta_depart...
# 120868       NaN  http://www.properati.com.ar/1cig6_venta_depart...
# 120869       NaN  http://www.properati.com.ar/1cig7_venta_depart...
# 120870       NaN  http://www.properati.com.ar/1cig8_venta_depart...
# 120871       NaN  http://www.properati.com.ar/1cig9_venta_depart...
#
#                                               description  \
# 120867                  Excelente piso sobre Av. Alber...
# 120868                  Semipiso de 3 ambientes todo r...
# 120869                  Piso de 4 ambientes con depend...
# 120870                  IMPECABLE TORRE COY III – DEPA...
# 120871                  IMPECABLE TORRE COY III – HERM...
#
#                               title  \
# 120867     Departamento - Caballito
# 120868     Departamento - Caballito
# 120869     Departamento - Caballito
# 120870  Departamento - Palermo Soho
# 120871  Departamento - Palermo Soho
#
#                                           image_thumbnail
# 120867  https://thumbs4.properati.com/4/-31MEB4-qkkrEr...
# 120868  https://thumbs4.properati.com/1/JEuG0GTRN1cGe3...
# 120869  https://thumbs4.properati.com/9/OnrB2dOwaG-cG5...
# 120870  https://thumbs4.properati.com/6/M8EZL8DFe9Fb8t...
# 120871  https://thumbs4.properati.com/1/lQgj0j1UMVlAQj...
#
# [5 rows x 27 columns]

# %%
ps08.groupby('state_name').count()
# Out:
#                                id  created_on  operation  property_type  \
# state_name
# Bs.As. G.B.A. Zona Norte       46          46         46             46
# Bs.As. G.B.A. Zona Oeste        8           8          8              8
# Bs.As. G.B.A. Zona Sur         13          13         13             13
# Buenos Aires Costa Atlántica    3           3          3              3
# Capital Federal               192         192        192            192
# Corrientes                      1           1          1              1
# Córdoba                        58          58         58             58
# Mendoza                         2           2          2              2
# San Luis                        1           1          1              1
# Santa Fe                       24          24         24             24
# Tucumán                         5           5          5              5
#
#                               place_name  place_with_parent_names  \
# state_name
# Bs.As. G.B.A. Zona Norte              46                       46
# Bs.As. G.B.A. Zona Oeste               8                        8
# Bs.As. G.B.A. Zona Sur                13                       13
# Buenos Aires Costa Atlántica           3                        3
# Capital Federal                      192                      192
# Corrientes                             1                        1
# Córdoba                               58                       58
# Mendoza                                2                        2
# San Luis                               1                        1
# Santa Fe                              24                       24
# Tucumán                                5                        5
#
#                               country_name  geonames_id  lat-lon  lat  \
# state_name
# Bs.As. G.B.A. Zona Norte                46           42        0    0
# Bs.As. G.B.A. Zona Oeste                 8            8        0    0
# Bs.As. G.B.A. Zona Sur                  13           11        0    0
# Buenos Aires Costa Atlántica             3            1        0    0
# Capital Federal                        192          188       38   38
# Corrientes                               1            1        0    0
# Córdoba                                 58           58        1    1
# Mendoza                                  2            2        0    0
# San Luis                                 1            1        0    0
# Santa Fe                                24           24        0    0
# Tucumán                                  5            3        0    0
#
#                                    ...         surface_covered_in_m2  \
# state_name                         ...
# Bs.As. G.B.A. Zona Norte           ...                            44
# Bs.As. G.B.A. Zona Oeste           ...                             7
# Bs.As. G.B.A. Zona Sur             ...                            13
# Buenos Aires Costa Atlántica       ...                             3
# Capital Federal                    ...                           186
# Corrientes                         ...                             1
# Córdoba                            ...                             6
# Mendoza                            ...                             2
# San Luis                           ...                             1
# Santa Fe                           ...                            18
# Tucumán                            ...                             1
#
#                               price_usd_per_m2  price_per_m2  floor  rooms  \
# state_name
# Bs.As. G.B.A. Zona Norte                    29            37      0      0
# Bs.As. G.B.A. Zona Oeste                     1             1      0      0
# Bs.As. G.B.A. Zona Sur                       5            11      0      0
# Buenos Aires Costa Atlántica                 2             3      0      0
# Capital Federal                             48            54      0      0
# Corrientes                                   1             1      0      0
# Córdoba                                     50             4      0      0
# Mendoza                                      1             2      0      0
# San Luis                                     0             1      0      0
# Santa Fe                                     7             7      0      0
# Tucumán                                      1             1      0      0
#
#                               expenses  properati_url  description  title  \
# state_name
# Bs.As. G.B.A. Zona Norte             8             46           46     46
# Bs.As. G.B.A. Zona Oeste             0              8            8      8
# Bs.As. G.B.A. Zona Sur               3             13           13     13
# Buenos Aires Costa Atlántica         1              3            3      3
# Capital Federal                     31            192          192    192
# Corrientes                           1              1            1      1
# Córdoba                              1             58           58     58
# Mendoza                              2              2            2      2
# San Luis                             0              1            1      1
# Santa Fe                             2             24           24     24
# Tucumán                              2              5            5      5
#
#                               image_thumbnail
# state_name
# Bs.As. G.B.A. Zona Norte                   45
# Bs.As. G.B.A. Zona Oeste                    7
# Bs.As. G.B.A. Zona Sur                     13
# Buenos Aires Costa Atlántica                3
# Capital Federal                           188
# Corrientes                                  1
# Córdoba                                    19
# Mendoza                                     2
# San Luis                                    1
# Santa Fe                                   22
# Tucumán                                     5
#
# [11 rows x 26 columns]

# %%
#Filtramos las propiedades de capital federal
ps08 = ps08[ps08['state_name'].str.contains('ederal')]['state_name'].count()
# Out:
# 192

# %%
#Tenemos sólo 192 propiedades de capital federal
ps08 = ps08[ps08['state_name'].str.contains('ederal')]

# %% [markdown]
# # ¿De qué tamaño son las propiedades más demandadas?¿A qué barrios/comunas corresponden?

# %%
#Hacemos un analisis preliminar para el mes de agosto
#Vemos lo que tenemos por ahora
ps08.head(2)
ps08.dtypes
# Out:
# id                                    object
# created_on                    datetime64[ns]
# operation                             object
# property_type                         object
# place_name                            object
# place_with_parent_names               object
# country_name                          object
# state_name                            object
# geonames_id                          float64
# lat-lon                               object
# lat                                  float64
# lon                                  float64
# price                                float64
# currency                              object
# price_aprox_local_currency           float64
# price_aprox_usd                      float64
# surface_total_in_m2                  float64
# surface_covered_in_m2                float64
# price_usd_per_m2                     float64
# price_per_m2                         float64
# floor                                float64
# rooms                                float64
# expenses                             float64
# properati_url                         object
# description                           object
# title                                 object
# image_thumbnail                       object
# dtype: object

# %%
more_d = ps08.groupby('surface_total_in_m2').count().sort_values('id',ascending=False)[["id"]]
more_d = more_d.rename(columns={'id':'count'})
more_d
# Out:
#                      count
# surface_total_in_m2
# 39.0                    27
# 46.0                    21
# 38.0                    16
# 71.0                    11
# 62.0                     6
# 51.0                     5
# 35.0                     4
# 37.0                     4
# 121.0                    4
# 73.0                     4
# 91.0                     4
# 74.0                     4
# 80.0                     3
# 47.0                     3
# 84.0                     3
# 45.0                     3
# 64.0                     3
# 90.0                     2
# 78.0                     2
# 77.0                     2
# 113.0                    2
# 157.0                    2
# 600.0                    2
# 42.0                     2
# 65.0                     2
# 56.0                     2
# 40.0                     2
# 170.0                    1
# 138.0                    1
# 141.0                    1
# ...                    ...
# 169.0                    1
# 67.0                     1
# 178.0                    1
# 120.0                    1
# 200.0                    1
# 246.0                    1
# 287.0                    1
# 320.0                    1
# 364.0                    1
# 403.0                    1
# 182.0                    1
# 117.0                    1
# 69.0                     1
# 115.0                    1
# 70.0                     1
# 58.0                     1
# 53.0                     1
# 52.0                     1
# 50.0                     1
# 83.0                     1
# 49.0                     1
# 48.0                     1
# 44.0                     1
# 94.0                     1
# 95.0                     1
# 100.0                    1
# 106.0                    1
# 110.0                    1
# 43.0                     1
# 29.0                     1
#
# [63 rows x 1 columns]

# %%
#Para agosto:
#La mayor cantidad de propiedades vendidas corresponde a las comprendidas entre los 38m2 y los 46m2.
more_d.head(30).plot.bar(title='Propiedades mas publicadas por m2 en 08/2017')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ps08.to_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-08.csv")

# %%
#Tomamos un rango de tiempo más grande y analizamos las propiedades correspondientes al año actual.
ps08 = pd.read_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-08.csv")

# %%
ps08.count()['id']
# Out:
# 192

# %%
ps07 = pd.read_csv("../../home/lucas/academico/datos/tp1/csv_originales/properati-AR-2017-07-01-properties-sell-six_months.csv")

# %%
ps07.head(2)
# Out:
#                                          id  created_on operation  \
# 0  e3cb52c36e2210586ddf90fd0443261ea2e5511f  2017-01-01      sell
# 1  f1840b53eab0efe00661a89fb38a2c14bb159708  2017-01-01      sell
#
#   property_type place_name                            place_with_parent_names  \
# 0         house    Quilmes  |Argentina|Bs.As. G.B.A. Zona Sur|Quilmes|Quil...
# 1         house    Punilla                        |Argentina|Córdoba|Punilla|
#
#   country_name              state_name  geonames_id                lat-lon  \
# 0    Argentina  Bs.As. G.B.A. Zona Sur    3429651.0  -34.744616,-58.277365
# 1    Argentina                 Córdoba    3839996.0  -31.447378,-64.518655
#
#                          ...                          surface_covered_in_m2  \
# 0                        ...                                            NaN
# 1                        ...                                          185.0
#
#    price_usd_per_m2  price_per_m2 floor  rooms  expenses  \
# 0               NaN           NaN   NaN    NaN       NaN
# 1               NaN    702.702703   NaN    5.0       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/14mll_venta_casa_q...
# 1  http://www.properati.com.ar/14mlv_venta_casa_p...
#
#                                          description  \
# 0  Corredor Responsable: Martin Veltri - C.M.Q 80...
# 1  Corredor Responsable: DANIELA E. CASTRO - CPCP...
#
#                                   title  \
# 0                 Casa en Venta Quilmes
# 1  Inverti! 2 Casas C/Pileta Carlos Paz
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/7/JUtDrSg4Bi2svp...
# 1  https://thumbs4.properati.com/6/6rEVlpVxiop3Bh...
#
# [2 rows x 27 columns]

# %%
ps07.dtypes
# Out:
# id                             object
# created_on                     object
# operation                      object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# description                    object
# title                          object
# image_thumbnail                object
# dtype: object

# %%
ps07['created_on'] = ps07['created_on'].apply(pd.to_datetime)

# %%
ps07.dtypes
# Out:
# id                                    object
# created_on                    datetime64[ns]
# operation                             object
# property_type                         object
# place_name                            object
# place_with_parent_names               object
# country_name                          object
# state_name                            object
# geonames_id                          float64
# lat-lon                               object
# lat                                  float64
# lon                                  float64
# price                                float64
# currency                              object
# price_aprox_local_currency           float64
# price_aprox_usd                      float64
# surface_total_in_m2                  float64
# surface_covered_in_m2                float64
# price_usd_per_m2                     float64
# price_per_m2                         float64
# floor                                float64
# rooms                                float64
# expenses                             float64
# properati_url                         object
# description                           object
# title                                 object
# image_thumbnail                       object
# dtype: object

# %%
#Como este archivo corresponde a julio limpiamos los registros correspondientes a otros meses
ps07 = ps07[(ps07['created_on'] >= '2017-07-01') & (ps07['created_on'] <= '2017-07-31')]
ps07.head(2)
# Out:
#                                              id created_on operation  \
# 80236  18fc384e6b758175d6663faf84efad355d4c5c54 2017-07-01      sell
# 80237  d3fa6320ac1861afe9a4fe98cb713d29798f3352 2017-07-01      sell
#
#       property_type        place_name  \
# 80236         house  Villa del Parque
# 80237         house    Coronel Moldes
#
#                             place_with_parent_names country_name  \
# 80236  |Argentina|Capital Federal|Villa del Parque|    Argentina
# 80237              |Argentina|Salta|Coronel Moldes|    Argentina
#
#             state_name  geonames_id                  lat-lon  \
# 80236  Capital Federal    3427455.0  -34.5974907,-58.4866893
# 80237            Salta    3860179.0   -25.2804197,-65.477208
#
#                              ...                          \
# 80236                        ...
# 80237                        ...
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2 floor  rooms  \
# 80236                    NaN       1253.164557           NaN   NaN    4.0
# 80237                   78.0         53.368832  17628.205128   NaN    3.0
#
#        expenses                                      properati_url  \
# 80236       NaN  http://www.properati.com.ar/19nl9_venta_casa_v...
# 80237       NaN  http://www.properati.com.ar/19nla_venta_casa_c...
#
#                                              description       title  \
# 80236  Excelente Chalet de 4 ambientes, en dos planta...  Casa venta
# 80237  Hermosas casas en construcción, en la compra v...  Casa venta
#
#                                          image_thumbnail
# 80236  https://thumbs4.properati.com/7/HLj1yuBmHYj6Pv...
# 80237  https://thumbs4.properati.com/9/iG3vV-AqbDvbpk...
#
# [2 rows x 27 columns]

# %%
ps07.count()
# Out:
# id                            22
# created_on                    22
# operation                     22
# property_type                 22
# place_name                    22
# place_with_parent_names       22
# country_name                  22
# state_name                    22
# geonames_id                   20
# lat-lon                       22
# lat                           22
# lon                           22
# price                         21
# currency                      21
# price_aprox_local_currency    21
# price_aprox_usd               21
# surface_total_in_m2           22
# surface_covered_in_m2         15
# price_usd_per_m2              21
# price_per_m2                  15
# floor                          0
# rooms                         22
# expenses                       6
# properati_url                 22
# description                   22
# title                         22
# image_thumbnail               22
# dtype: int64

# %%
ps07.to_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-07.csv")

# %%
#Junio,Mayo,Abril,Marzo,Febrero y Enero
ps06 = pd.read_csv("../../home/lucas/academico/datos/tp1/csv_originales/properati-AR-2017-06-01-properties-sell.csv")
ps06.count()['id']
# Out:
# 85790

# %%
ps06['created_on'] = ps06['created_on'].apply(pd.to_datetime)
ps06 = ps06[(ps06['created_on'] >= '2017-06-01') & (ps06['created_on'] <= '2017-06-30')]
print("Cantidad procesados: "+str(ps06.count()['id']))
ps06 = ps06[ps06['state_name'].str.contains('ederal')]
print("Cantidad procesados CABA: "+str(ps06.count()['id']))
ps06.head(2)
# Out:
# Cantidad procesados: 3323
# Cantidad procesados CABA: 3323
#                                              id created_on operation  \
# 74493  2ba91ce3876eaa42a31dcf0ac7405bbf9a848461 2017-06-01      sell
# 74494  d7d1a5b31c2245e6602d83f809762db63012e932 2017-06-01      sell
#
#       property_type    place_name                   place_with_parent_names  \
# 74493     apartment        Flores        |Argentina|Capital Federal|Flores|
# 74494     apartment  Constitución  |Argentina|Capital Federal|Constitución|
#
#       country_name       state_name  geonames_id                lat-lon  \
# 74493    Argentina  Capital Federal    3433918.0  -34.632409,-58.461642
# 74494    Argentina  Capital Federal    3435257.0                    NaN
#
#                              ...                          \
# 74493                        ...
# 74494                        ...
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2 floor  rooms  \
# 74493                  123.0               NaN   1788.617886   4.0    4.0
# 74494                   70.0               NaN   1000.000000   NaN    2.0
#
#        expenses                                      properati_url  \
# 74493       NaN  http://www.properati.com.ar/18s3e_venta_depart...
# 74494       NaN  http://www.properati.com.ar/18s3f_venta_depart...
#
#                                              description  \
# 74493  Corredor Responsable: Mariano Aufseher - CUCIC...
# 74494  Corredor Responsable: Mariano Aufseher - CUCIC...
#
#                                       title  \
# 74493  ¡VENTA DEPTO.4 AMB C/DEP. EN FLORES!
# 74494                AMPLIO 2 AMB RECICLADO
#
#                                          image_thumbnail
# 74493  https://thumbs4.properati.com/0/aJeQzi1XZDCQL4...
# 74494  https://thumbs4.properati.com/6/b0_fkg_8CR6Q3s...
#
# [2 rows x 27 columns]

# %%
ps06.to_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-06.csv")

# %%
ps05 = pd.read_csv("../../home/lucas/academico/datos/tp1/csv_originales/properati-AR-2017-05-01-properties-sell.csv")
ps05.count()['id']
# Out:
# 82377

# %%
ps05['created_on'] = ps05['created_on'].apply(pd.to_datetime)
ps05 = ps05[(ps05['created_on'] >= '2017-05-01') & (ps05['created_on'] <= '2017-05-31')]
print("Cantidad procesados: "+str(ps05.count()['id']))
ps05 = ps05[ps05['state_name'].str.contains('ederal')]
print("Cantidad procesados CABA: "+str(ps05.count()['id']))
ps05.head(2)
#No existen registros para el mes de Mayo
# Out:
# Cantidad procesados: 18629
# Cantidad procesados CABA: 5577
#                                              id created_on operation  \
# 63762  60f9d93b3eb34996c9dc48e297a3cf20b1b3b7ce 2017-05-01      sell
# 63763  2dc940ad3b8cc3bdb3c53122940e7b3f5196cb7e 2017-05-01      sell
#
#       property_type    place_name                   place_with_parent_names  \
# 63762     apartment  Barrio Norte  |Argentina|Capital Federal|Barrio Norte|
# 63763     apartment  Barrio Norte  |Argentina|Capital Federal|Barrio Norte|
#
#       country_name       state_name  geonames_id                lat-lon  \
# 63762    Argentina  Capital Federal    3436109.0  -34.585958,-58.403988
# 63763    Argentina  Capital Federal    3436109.0  -34.585958,-58.403988
#
#                              ...                          \
# 63762                        ...
# 63763                        ...
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2 floor  rooms  \
# 63762                  162.0               NaN   4091.839506   1.0    4.0
# 63763                  134.0               NaN   4085.335821   1.0    4.0
#
#        expenses                                      properati_url  \
# 63762       NaN  http://www.properati.com.ar/17v8g_venta_depart...
# 63763       NaN  http://www.properati.com.ar/17v8h_venta_depart...
#
#                                              description  \
# 63762  Corredor Responsable: Luis Varela - CSI 5527 /...
# 63763  Corredor Responsable: Luis Varela - CSI 5527 /...
#
#                                               title  \
# 63762  BARRIO NORTE THE EDGE OPORTUNIDAD 4 AMB  SEG
# 63763  BARRIO NORTE THE EDGE OPORTUNIDAD 4 AMB  SEG
#
#                                          image_thumbnail
# 63762  https://thumbs4.properati.com/2/pVqOfHuxL6IHa6...
# 63763  https://thumbs4.properati.com/2/pVqOfHuxL6IHa6...
#
# [2 rows x 27 columns]

# %%
# Deberían ser todas las operaciones tipo sell
assert ps05.count()['id'] == ps05[ps05['operation'] == 'sell'].count()['id']

# %%
ps05.to_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-05.csv")

# %%
#Abril
ps04 = pd.read_csv("../../home/lucas/academico/datos/tp1/csv_originales/properati-AR-2017-04-01-properties-sell.csv")
print("Cantidad de registros originales: "+str(ps04.count()['id']))
print("")
ps04['created_on'] = ps04['created_on'].apply(pd.to_datetime)
ps04 = ps04[(ps04['created_on'] >= '2017-04-01') & (ps04['created_on'] <= '2017-04-30')]
print("Cantidad procesados: "+str(ps04.count()['id']))
ps04 = ps04[ps04['state_name'].str.contains('ederal')]
print("Cantidad procesados CABA: "+str(ps04.count()['id']))


assert ps04.count()['id'] == ps04[ps04['operation'] == 'sell'].count()['id']

ps04.to_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-04.csv")

ps04.head(2)
# Out:
# Cantidad de registros originales: 70631
#
# Cantidad procesados: 15650
# Cantidad procesados CABA: 5250
#                                              id created_on operation  \
# 54278  cbec458c56f942a8fe61a3d30c891e0754c02a09 2017-04-01      sell
# 54287  3b89190788c6d3a4748b5451278647e6099ffae4 2017-04-01      sell
#
#       property_type       place_name      place_with_parent_names  \
# 54278         house  Capital Federal  |Argentina|Capital Federal|
# 54287         house  Capital Federal  |Argentina|Capital Federal|
#
#       country_name       state_name  geonames_id lat-lon  \
# 54278    Argentina  Capital Federal    3433955.0     NaN
# 54287    Argentina  Capital Federal    3433955.0     NaN
#
#                              ...                          \
# 54278                        ...
# 54287                        ...
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2 floor  rooms  \
# 54278                  440.0        878.594249   2500.000000   NaN    NaN
# 54287                  118.0       1266.375546   2457.627119   NaN    NaN
#
#        expenses                                      properati_url  \
# 54278       NaN  http://www.properati.com.ar/16zw2_venta_casa_b...
# 54287       NaN  http://www.properati.com.ar/16zwl_venta_casa_b...
#
#                                              description  \
# 54278  EXCELENTE CHALET DE 1 PLANTA EN LA HORQUETA. T...
# 54287  Casa en la Horqueta, desarrollada en dos plant...
#
#                                                    title  \
# 54278  Casa 1252m² con Dependencias en Reclus, Eliseo...
# 54287  Casa 229m² con Cochera, Argentina, Capital Fed...
#
#                                          image_thumbnail
# 54278  https://thumbs4.properati.com/2/mGJZIuZc8iizeX...
# 54287  https://thumbs4.properati.com/3/BnO7mVFc7XZcq5...
#
# [2 rows x 27 columns]

# %%
#Marzo
ps03 = pd.read_csv("../../home/lucas/academico/datos/tp1/csv_originales/properati-AR-2017-03-01-properties-sell.csv")
print("Cantidad de registros originales: "+str(ps03.count()['id']))
print("")
ps03['created_on'] = ps03['created_on'].apply(pd.to_datetime)
ps03 = ps03[(ps03['created_on'] >= '2017-03-01') & (ps03['created_on'] <= '2017-03-31')]
print("Cantidad procesados: "+str(ps03.count()['id']))
ps03 = ps03[ps03['state_name'].str.contains('ederal')]
print("Cantidad procesados CABA: "+str(ps03.count()['id']))


assert ps03.count()['id'] == ps03[ps03['operation'] == 'sell'].count()['id']

ps03.to_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-03.csv")

ps03.head(2)
# Out:
# Cantidad de registros originales: 65521
#
# Cantidad procesados: 15288
# Cantidad procesados CABA: 5438
#                                              id created_on operation  \
# 45459  ae36b32cc198bad74af8e3d5cdfd00a93a4c43ca 2017-03-01      sell
# 45464  87354eba6b4a0e87ff45af971b930c7b918034cf 2017-03-01      sell
#
#       property_type       place_name                 place_with_parent_names  \
# 45459     apartment       Colegiales  |Argentina|Capital Federal|Colegiales|
# 45464         store  Capital Federal             |Argentina|Capital Federal|
#
#       country_name       state_name  geonames_id                  lat-lon  \
# 45459    Argentina  Capital Federal    3435356.0  -34.5826411,-58.4518346
# 45464    Argentina  Capital Federal    3433955.0  -34.5972002,-58.3918164
#
#                              ...                          \
# 45459                        ...
# 45464                        ...
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2 floor  rooms  \
# 45459                   41.0       3229.166667   3780.487805   NaN    2.0
# 45464                   60.0       5000.000000   5000.000000   NaN    4.0
#
#        expenses                                      properati_url  \
# 45459       NaN  http://www.properati.com.ar/1622a_venta_depart...
# 45464    3800.0  http://www.properati.com.ar/1622o_venta_local_...
#
#                                              description  \
# 45459  Excelente 2 ambientes en edificio único. Antig...
# 45464  Distinguido local en Recoleta. Cuenta con una ...
#
#                                                    title  \
# 45459  ESTUPENDO 2 AMB EN COLEGIALES - EXCELENTES AME...
# 45464                                        Local venta
#
#                                          image_thumbnail
# 45459  https://thumbs4.properati.com/6/aVxV3cnlFqeoOH...
# 45464  https://thumbs4.properati.com/7/MYi74ADuSMzG2C...
#
# [2 rows x 27 columns]

# %%
#Febrero
ps02 = pd.read_csv("../../home/lucas/academico/datos/tp1/csv_originales/properati-AR-2017-02-01-properties-sell.csv")
print("Cantidad de registros originales: "+str(ps02.count()['id']))
print("")
ps02['created_on'] = ps02['created_on'].apply(pd.to_datetime)
ps02 = ps02[(ps02['created_on'] >= '2017-02-01') & (ps02['created_on'] <= '2017-02-28')]
print("Cantidad procesados: "+str(ps02.count()['id']))
ps02 = ps02[ps02['state_name'].str.contains('ederal')]
print("Cantidad procesados CABA: "+str(ps02.count()['id']))

assert ps02.count()['id'] == ps02[ps02['operation'] == 'sell'].count()['id']

ps02.head(2)

ps02.to_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-02.csv")
# Out:
# Cantidad de registros originales: 64479
#
# Cantidad procesados: 14166
# Cantidad procesados CABA: 3575

# %%
#Enero
ps01 = pd.read_csv("../../home/lucas/academico/datos/tp1/csv_originales/properati-AR-2017-01-01-properties-sell.csv.gz")
print("Cantidad de registros originales: "+str(ps01.count()['id']))
print("")
ps01['created_on'] = ps01['created_on'].apply(pd.to_datetime)
ps01 = ps01[(ps01['created_on'] >= '2017-01-01') & (ps01['created_on'] <= '2017-01-31')]
print("Cantidad procesados: "+str(ps01.count()['id']))
ps01 = ps01[ps01['state_name'].str.contains('ederal')]
print("Cantidad procesados CABA: "+str(ps01.count()['id']))

assert ps01.count()['id'] == ps01[ps01['operation'] == 'sell'].count()['id']

ps01.head(2)

ps01.to_csv("../../home/lucas/academico/datos/tp1/properati-sell-processed-01.csv")
# Out:
# Cantidad de registros originales: 59806
#
# Cantidad procesados: 11815
# Cantidad procesados CABA: 3154

# %%
frames = [ps01,ps02,ps03,ps04,ps05,ps06,ps07,ps08]
total = pd.concat(frames)

# %%
#Juntamos todos los registros para hacer un plot
assert total.count()['id'] == int(ps01.count()['id']) + int(ps02.count()['id']) + int(ps03.count()['id']) + int(ps04.count()['id']) + int(ps05.count()['id']) + int(ps06.count()['id']) + int(ps07.count()['id']) + int(ps08.count()['id']) 
print('TEST OK')
# Out:
# TEST OK

# %%
ps08['created_on'] = ps08['created_on'].apply(pd.to_datetime)

# %%
total.dtypes
# Out:
# Unnamed: 0                           float64
# country_name                          object
# created_on                    datetime64[ns]
# currency                              object
# description                           object
# expenses                             float64
# floor                                float64
# geonames_id                          float64
# id                                    object
# image_thumbnail                       object
# lat                                  float64
# lat-lon                               object
# lon                                  float64
# operation                             object
# place_name                            object
# place_with_parent_names               object
# price                                float64
# price_aprox_local_currency           float64
# price_aprox_usd                      float64
# price_per_m2                         float64
# price_usd_per_m2                     float64
# properati_url                         object
# property_type                         object
# rooms                                float64
# state_name                            object
# surface_covered_in_m2                float64
# surface_total_in_m2                  float64
# title                                 object
# dtype: object

# %%
s = total.groupby('surface_covered_in_m2').count().sort_values('id',ascending=False)['id']
s = s.reset_index().rename(columns={'id':'count'})
s.head(6)
# Out:
#    surface_covered_in_m2  count
# 0                   30.0    826
# 1                   40.0    762
# 2                   35.0    628
# 3                   50.0    564
# 4                   34.0    556
# 5                   38.0    533

# %%
s.tail(3)
# Out:
#      surface_covered_in_m2  count
# 547                  284.0      1
# 548                  520.0      1
# 549                 7630.0      1

# %%
#Removemos casos de mucha superficie que no parece tener sentido
s.tail(5)
s = s[s['surface_covered_in_m2'] < 500]
s.tail(5)
# Out:
#      surface_covered_in_m2  count
# 541                  488.0      1
# 543                  493.0      1
# 544                  495.0      1
# 545                    7.0      1
# 547                  284.0      1

# %%
#plt.hist(s,alpha=0.5,stacked=True, bins=10,x='test')
#s.plot(x='surface_covered_in_m2',y='count')
s.plot(x='surface_covered_in_m2',y='count',kind='scatter',title='Propiedades mas publicadas por m2 en 2017')#line
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Se puede ver en el grafico que a medida que aumenta el tamaño de la propiedad la cantidad de publicaciones disminuye.
#Entonces las propiedades más publicadas(ofertadas) ó más vendidas son las que tienen pocos metros cuadrados.

# %%
#Recortemos el rango de las propiedades para aquellas hasta 100 metros cuadrados
s100 = s[s['surface_covered_in_m2'] < 101]

# %%
s100.plot(x='surface_covered_in_m2',y='count',kind='scatter',title='Propiedades mas publicadas por m2 en 2017')#line

#x = s100['surface_covered_in_m2']
#y = s100['count']
#z = np.polyfit(x, y, 1)

#p = np.poly1d(z)
#plt.plot(x,p(x),"r--")

#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#En el gráfico anterior se puede ver con mayor precisión que las unidades de entre 30 ~ 60 m2 son las mas vendidas.

# %% [markdown]
# # ¿A qué barrios ó comunas corresponden las unidades más publicadas?

# %%
#Sobre la base de los registros procesados tomamos agrupamos por barrios
total.head(2)
total.dtypes
# Out:
# Unnamed: 0                           float64
# country_name                          object
# created_on                    datetime64[ns]
# currency                              object
# description                           object
# expenses                             float64
# floor                                float64
# geonames_id                          float64
# id                                    object
# image_thumbnail                       object
# lat                                  float64
# lat-lon                               object
# lon                                  float64
# operation                             object
# place_name                            object
# place_with_parent_names               object
# price                                float64
# price_aprox_local_currency           float64
# price_aprox_usd                      float64
# price_per_m2                         float64
# price_usd_per_m2                     float64
# properati_url                         object
# property_type                         object
# rooms                                float64
# state_name                            object
# surface_covered_in_m2                float64
# surface_total_in_m2                  float64
# title                                 object
# dtype: object

# %%
total[['currency','description','surface_covered_in_m2','rooms','property_type']].head(2)
# Out:
#       currency                                        description  \
# 35366      USD  Corredor Responsable: Juan Carlos Treco - CUCI...
# 35367      USD  Corredor Responsable: Juan Carlos Treco - CUCI...
#
#        surface_covered_in_m2  rooms property_type
# 35366                   43.0    1.0     apartment
# 35367                   38.0    1.0     apartment

# %%
total[['price_aprox_local_currency','floor','operation','place_name']].head(5)
# Out:
#        price_aprox_local_currency  floor operation            place_name
# 35366                  1740566.50    NaN      sell         Villa Urquiza
# 35367                  1435568.15    NaN      sell         Villa Urquiza
# 35369                  1277480.00    NaN      sell             San Telmo
# 35371                  3193700.00    NaN      sell  Centro / Microcentro
# 35380                  2714645.00    NaN      sell                Flores

# %% [markdown]
# # ¿A qué barrios/comunas corresponden las unidades más publicadas?

# %%
total.head(5)
# Out:
#        Unnamed: 0 country_name created_on currency  \
# 35366         NaN    Argentina 2017-01-01      USD
# 35367         NaN    Argentina 2017-01-01      USD
# 35369         NaN    Argentina 2017-01-01      USD
# 35371         NaN    Argentina 2017-01-01      USD
# 35380         NaN    Argentina 2017-01-01      USD
#
#                                              description  expenses  floor  \
# 35366  Corredor Responsable: Juan Carlos Treco - CUCI...       NaN    NaN
# 35367  Corredor Responsable: Juan Carlos Treco - CUCI...       NaN    NaN
# 35369  Corredor Responsable: Ariel Champanier - CUCIC...       NaN    NaN
# 35371  Corredor Responsable: Cristian Arnal Ponti - C...       NaN    NaN
# 35380  Departamento de 3 ambientes con dependencia, e...       NaN    NaN
#
#        geonames_id                                        id  \
# 35366    3433775.0  2e61de575b2653733dc55aaed4b08a1e9ae13563
# 35367    3433775.0  5a66865f29a02dbfa89d04ad66e91162c368eb99
# 35369    3428113.0  3efd73a285f946226b724d288ed42dae9d450d86
# 35371    3435548.0  d3f8158c772e668eb92e239c6d9979c8db2711d7
# 35380    3433918.0  5a330340c7de7f7fc1c12a649de8164b8b0df60b
#
#                                          image_thumbnail  \
# 35366  https://thumbs4.properati.com/7/q07Sye4wLYyM3m...
# 35367  https://thumbs4.properati.com/8/HfKdACQrN2vqJi...
# 35369  https://thumbs4.properati.com/9/Tg9Jl-mK-O-8IP...
# 35371  https://thumbs4.properati.com/8/ndSSd-0jIfeez6...
# 35380  https://thumbs4.properati.com/4/VZYqoMHnnjzxn3...
#
#                              ...                          price_aprox_usd  \
# 35366                        ...                                 109000.0
# 35367                        ...                                  89900.0
# 35369                        ...                                  80000.0
# 35371                        ...                                 200000.0
# 35380                        ...                                 170000.0
#
#        price_per_m2  price_usd_per_m2  \
# 35366   2534.883721               NaN
# 35367   2365.789474               NaN
# 35369   1702.127660               NaN
# 35371  10000.000000               NaN
# 35380   1888.888889            1700.0
#
#                                            properati_url property_type rooms  \
# 35366  http://www.properati.com.ar/14mm2_venta_depart...     apartment   1.0
# 35367  http://www.properati.com.ar/14mm3_venta_depart...     apartment   1.0
# 35369  http://www.properati.com.ar/14mo0_venta_depart...     apartment   3.0
# 35371  http://www.properati.com.ar/14moh_venta_local_...         store   NaN
# 35380  http://www.properati.com.ar/14mq6_venta_depart...     apartment   NaN
#
#             state_name  surface_covered_in_m2  surface_total_in_m2  \
# 35366  Capital Federal                   43.0                  NaN
# 35367  Capital Federal                   38.0                  NaN
# 35369  Capital Federal                   47.0                  NaN
# 35371  Capital Federal                   20.0                  NaN
# 35380  Capital Federal                   90.0                100.0
#
#                                                    title
# 35366      2 AMBIENTES A ESTRENAR C/BALCÓN VILLA URQUIZA
# 35367   2 Ambientes / Monoambiente con balcon a estrenar
# 35369            Depto 3 amb  San Telmo Apto Credito!!!!
# 35371  Importante local en zona de alto trafico peatonal
# 35380  Departamento de 3 ambientes con dependencia de...
#
# [5 rows x 28 columns]

# %%
total_sell = total
#total_sell['count'] = 1
total_sell.head(5)
# Out:
#        Unnamed: 0 country_name created_on currency  \
# 35366         NaN    Argentina 2017-01-01      USD
# 35367         NaN    Argentina 2017-01-01      USD
# 35369         NaN    Argentina 2017-01-01      USD
# 35371         NaN    Argentina 2017-01-01      USD
# 35380         NaN    Argentina 2017-01-01      USD
#
#                                              description  expenses  floor  \
# 35366  Corredor Responsable: Juan Carlos Treco - CUCI...       NaN    NaN
# 35367  Corredor Responsable: Juan Carlos Treco - CUCI...       NaN    NaN
# 35369  Corredor Responsable: Ariel Champanier - CUCIC...       NaN    NaN
# 35371  Corredor Responsable: Cristian Arnal Ponti - C...       NaN    NaN
# 35380  Departamento de 3 ambientes con dependencia, e...       NaN    NaN
#
#        geonames_id                                        id  \
# 35366    3433775.0  2e61de575b2653733dc55aaed4b08a1e9ae13563
# 35367    3433775.0  5a66865f29a02dbfa89d04ad66e91162c368eb99
# 35369    3428113.0  3efd73a285f946226b724d288ed42dae9d450d86
# 35371    3435548.0  d3f8158c772e668eb92e239c6d9979c8db2711d7
# 35380    3433918.0  5a330340c7de7f7fc1c12a649de8164b8b0df60b
#
#                                          image_thumbnail  ...    price_per_m2  \
# 35366  https://thumbs4.properati.com/7/q07Sye4wLYyM3m...  ...     2534.883721
# 35367  https://thumbs4.properati.com/8/HfKdACQrN2vqJi...  ...     2365.789474
# 35369  https://thumbs4.properati.com/9/Tg9Jl-mK-O-8IP...  ...     1702.127660
# 35371  https://thumbs4.properati.com/8/ndSSd-0jIfeez6...  ...    10000.000000
# 35380  https://thumbs4.properati.com/4/VZYqoMHnnjzxn3...  ...     1888.888889
#
#       price_usd_per_m2                                      properati_url  \
# 35366              NaN  http://www.properati.com.ar/14mm2_venta_depart...
# 35367              NaN  http://www.properati.com.ar/14mm3_venta_depart...
# 35369              NaN  http://www.properati.com.ar/14mo0_venta_depart...
# 35371              NaN  http://www.properati.com.ar/14moh_venta_local_...
# 35380           1700.0  http://www.properati.com.ar/14mq6_venta_depart...
#
#       property_type rooms       state_name  surface_covered_in_m2  \
# 35366     apartment   1.0  Capital Federal                   43.0
# 35367     apartment   1.0  Capital Federal                   38.0
# 35369     apartment   3.0  Capital Federal                   47.0
# 35371         store   NaN  Capital Federal                   20.0
# 35380     apartment   NaN  Capital Federal                   90.0
#
#        surface_total_in_m2                                              title  \
# 35366                  NaN      2 AMBIENTES A ESTRENAR C/BALCÓN VILLA URQUIZA
# 35367                  NaN   2 Ambientes / Monoambiente con balcon a estrenar
# 35369                  NaN            Depto 3 amb  San Telmo Apto Credito!!!!
# 35371                  NaN  Importante local en zona de alto trafico peatonal
# 35380                100.0  Departamento de 3 ambientes con dependencia de...
#
#        count
# 35366      1
# 35367      1
# 35369      1
# 35371      1
# 35380      1
#
# [5 rows x 29 columns]

# %%
total.groupby(['place_name','surface_covered_in_m2']).count().sort_values('id',ascending=False)['id'].head(3)
# Out:
# place_name     surface_covered_in_m2
# Boedo          30.0                     412
# San Cristobal  40.0                     151
# Villa Crespo   34.0                      92
# Name: id, dtype: int64

# %%
#g_barrio = total.groupby(['place_name','surface_covered_in_m2']).count().sort_values('id',ascending=False)['id']
#g_barrio = 
g_barrio = total.groupby(['place_name']).count().sort_values('id',ascending=False)['id']
g_barrio = g_barrio.reset_index().rename(columns={'id':'count'})

# %%
g_barrio[g_barrio['place_name'].str.contains('Palermo')]#Belgrano,Nuñez,Colegiales,Palermo
#Chacarita,Agronomía,Villa Crespo,Villa Ortuzar
#str(a['place_name'][1])
# Out:
#            place_name  count
# 0             Palermo   2181
# 23  Palermo Hollywood    323
# 29       Palermo Soho    244
# 33      Palermo Chico    225
# 57      Palermo Viejo     39

# %%
#Para cada barrio teniendo en cuenta la frecuencia venta ordenamos descendentemente.
#Vamos a asignarle el número de comuna a la que corresponde cada barrio.
def set_comuna(place_name):
    p = str(place_name)
    if p == 'Retiro' or p == 'San Nicolás' or p == 'Puerto Madero' or p == 'San Telmo' or p == 'Monserrat' or p == 'Constitución':
        return 1
    if p == 'Recoleta':
        return 2
    if p == 'San Cristobal' or p == 'Balvanera':
        return 3
    if p == 'Boca' or p == 'Barracas' or p == 'Parque Patricios' or p == 'Pompeya':
        return 4
    if p == 'Almagro' or p == 'Boedo':
        return 5
    if p == 'Caballito':
        return 6
    if p == 'Flores' or p == 'Parque Chacabuco':
        return 7
    if p == 'Villa Soldati' or p == 'Villa Riachuelo' or p == 'Villa Lugano':
        return 8
    if p == 'Parque Avellaneda' or p == 'Liniers' or p == 'Mataderos':
        return 9
    if p == 'Villa Real' or p == 'Monte Castro' or p == 'Versalles' or p == 'Floresta' or p == 'Velez Sarsfield' or p == 'Villa Luro':
        return 10
    if p == 'Villa General Mitre' or p == 'Villa Devoto' or p == 'Villa del Parque' or p == 'Villa Santa Rita':
        return 11
    if p == 'Coghlan' or p == 'Saavedra' or p == 'Villa Urquiza' or p == 'Villa Pueyrredón':
        return 12
    if p == 'Belgrano' or p == 'Nuñez' or p == 'Colegiales':
        return 13
    if p == 'Palermo' or p == 'Palermo Hollywood' or p == 'Palermo Soho' or p == 'Palermo Chico' or p == 'Palermo Viejo':
        return 14
    if p == 'Chacarita' or p == 'Agronomía' or p == 'Villa Crespo' or p =='Villa Ortuzar':
        return 15

# %%
g_barrio['comuna'] = g_barrio['place_name'].apply(set_comuna)
g_barrio.head(3)
#set_comuna('a')
#a['place_name'][1]
# Out:
#   place_name  count  comuna
# 0    Palermo   2181    14.0
# 1  Caballito   2129     6.0
# 2   Belgrano   2051    13.0

# %%
#Filtro por los barrios del sur y del norte. Consideramos los barrios del sur de la capital a aquellos
#que corresponden a las comunas que se encuentran casí en su totalidad o en su totalidad al norte de la linea
#que divide la Av. Rivadavia. Los del sur los que se encuentran al sur de la av. Rivadavia:
#Comunas sur: 1(!),3,4,5(!),7(!),8,9
#Comunas norte: 2,6(!),10(!),11,12,..

#Los comunas marcadas con el signo(!) son las que corresponden al caso especial, en donde parte del territorio
#de la comuna esta cerca del 'limite' de la clasificación 'norte', 'sur'.

# %%
b_sur = g_barrio[(g_barrio['comuna'] > 0) & (g_barrio['comuna'] <= 9) & (g_barrio['comuna'] != 2) & (g_barrio['comuna'] != 6)]

b_norte = g_barrio[(g_barrio['comuna'] >= 10) | (g_barrio['comuna'] == 2) | (g_barrio['comuna'] == 6)]

# %%
ax = b_norte.plot.scatter(x='comuna',y='count',color='red',label='Norte')
b_sur.plot.scatter(x='comuna', y='count', color='green', label='Sur', ax=ax,title="Publicaciones por comunas 2017")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Hacemos una agrupación por comuna para los distintos barrios
#b_norte.groupby('comuna').count().sort_values('count')

bn_g = b_norte.sort_values(['count'],ascending=False).groupby('comuna').sum().sort_values('count',ascending=False).reset_index()

# %%
bs_g = b_sur.sort_values(['count'],ascending=False).groupby('comuna').sum().sort_values('count',ascending=False).reset_index()
bs_g
# Out:
#    comuna  count
# 0     1.0   2035
# 1     5.0   1997
# 2     3.0   1414
# 3     7.0   1313
# 4     4.0    975
# 5     9.0    816
# 6     8.0    204

# %%
ax = bn_g.plot.scatter(x='comuna',y='count',color='red',label='Norte')
bs_g.plot.scatter(x='comuna', y='count', color='green', label='Sur',ax=ax)
#bn_g.plot.scatter(x='comuna',y='count',color='red',label='Norte')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Se puede ver que la mayor cantidad de operaciones corresponde a los barrios de las comunas del Norte
# de la capital federal. En el gráfico este conjunto de comunas se ubica en la parte superior derecha.
# La comuna 4,8,9 son las que menos operaciones registran. Estas tres correspondientes al Sur.

# %%
#a.plot(x='place_name',y='count',kind='scatter').show()
#a.plot(x='comuna',y='count',kind='hist')
#a.plot()
#s = s.reset_index().rename(columns={'id':'count'})
#s.head(2)
#g_barrio.head(3)

#Con excepcion de la comuna 2(Recoleta) y 6(Caballito)

# %%
g_barrio
# Out:
# place_name      surface_covered_in_m2
# Boedo           30.0                     412
# San Cristobal   40.0                     151
# Villa Crespo    34.0                      92
# Caballito       36.0                      68
#                 34.0                      65
# San Cristobal   38.0                      63
# Caballito       41.0                      60
#                 40.0                      59
#                 33.0                      59
#                 45.0                      58
# Villa Crespo    40.0                      56
# Belgrano        35.0                      56
# Boedo           40.0                      56
# Palermo         35.0                      55
# Caballito       50.0                      54
# Palermo         45.0                      50
# Caballito       46.0                      50
# Belgrano        34.0                      49
# Palermo         50.0                      47
# Caballito       52.0                      47
# Boedo           35.0                      47
# Palermo         40.0                      46
# Monserrat       34.0                      45
# Caballito       75.0                      45
# Belgrano        40.0                      44
#                 42.0                      44
#                 45.0                      44
# Caballito       48.0                      43
# Palermo         0.0                       42
# San Cristobal   33.0                      42
#                                         ...
# Nuñez           162.0                      1
#                 157.0                      1
#                 23.0                       1
#                 152.0                      1
#                 26.0                       1
#                 29.0                       1
#                 31.0                       1
#                 69.0                       1
#                 88.0                       1
#                 89.0                       1
#                 90.0                       1
#                 96.0                       1
#                 98.0                       1
#                 101.0                      1
#                 108.0                      1
#                 111.0                      1
#                 113.0                      1
#                 114.0                      1
#                 117.0                      1
#                 121.0                      1
#                 123.0                      1
#                 125.0                      1
#                 128.0                      1
#                 129.0                      1
#                 135.0                      1
#                 136.0                      1
#                 141.0                      1
#                 143.0                      1
#                 147.0                      1
# Zona Portuaria  75.0                       1
# Name: id, Length: 6320, dtype: int64

# %%
g_barrio = g_barrio.reset_index().rename(columns={'id':'count'})

# %%
g_barrio.head(2)
# Out:
#       place_name  surface_covered_in_m2  count
# 0          Boedo                   30.0    412
# 1  San Cristobal                   40.0    151

# %%
g_barrio
# Out:
#           place_name  surface_covered_in_m2  count
# 0              Boedo                   30.0    412
# 1      San Cristobal                   40.0    151
# 2       Villa Crespo                   34.0     92
# 3          Caballito                   36.0     68
# 4          Caballito                   34.0     65
# 5      San Cristobal                   38.0     63
# 6          Caballito                   41.0     60
# 7          Caballito                   40.0     59
# 8          Caballito                   33.0     59
# 9          Caballito                   45.0     58
# 10      Villa Crespo                   40.0     56
# 11          Belgrano                   35.0     56
# 12             Boedo                   40.0     56
# 13           Palermo                   35.0     55
# 14         Caballito                   50.0     54
# 15           Palermo                   45.0     50
# 16         Caballito                   46.0     50
# 17          Belgrano                   34.0     49
# 18           Palermo                   50.0     47
# 19         Caballito                   52.0     47
# 20             Boedo                   35.0     47
# 21           Palermo                   40.0     46
# 22         Monserrat                   34.0     45
# 23         Caballito                   75.0     45
# 24          Belgrano                   40.0     44
# 25          Belgrano                   42.0     44
# 26          Belgrano                   45.0     44
# 27         Caballito                   48.0     43
# 28           Palermo                    0.0     42
# 29     San Cristobal                   33.0     42
# ...              ...                    ...    ...
# 6290           Nuñez                  162.0      1
# 6291           Nuñez                  157.0      1
# 6292           Nuñez                   23.0      1
# 6293           Nuñez                  152.0      1
# 6294           Nuñez                   26.0      1
# 6295           Nuñez                   29.0      1
# 6296           Nuñez                   31.0      1
# 6297           Nuñez                   69.0      1
# 6298           Nuñez                   88.0      1
# 6299           Nuñez                   89.0      1
# 6300           Nuñez                   90.0      1
# 6301           Nuñez                   96.0      1
# 6302           Nuñez                   98.0      1
# 6303           Nuñez                  101.0      1
# 6304           Nuñez                  108.0      1
# 6305           Nuñez                  111.0      1
# 6306           Nuñez                  113.0      1
# 6307           Nuñez                  114.0      1
# 6308           Nuñez                  117.0      1
# 6309           Nuñez                  121.0      1
# 6310           Nuñez                  123.0      1
# 6311           Nuñez                  125.0      1
# 6312           Nuñez                  128.0      1
# 6313           Nuñez                  129.0      1
# 6314           Nuñez                  135.0      1
# 6315           Nuñez                  136.0      1
# 6316           Nuñez                  141.0      1
# 6317           Nuñez                  143.0      1
# 6318           Nuñez                  147.0      1
# 6319  Zona Portuaria                   75.0      1
#
# [6320 rows x 3 columns]

# %%
#g_barrio.dtypes
#g_barrio.plot(x='surface_covered_in_m2',y='count',kind='scatter')#line
