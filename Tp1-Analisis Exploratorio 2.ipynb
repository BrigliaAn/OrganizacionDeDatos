# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib notebook

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # ¿Cuál es la diferencia de precios entre las propiedades emplazadas en el norte y sur de la capital federal ofertadas durante el año 2017?

# %%
props_2017 = pd.read_csv("../../home/lucas/academico/datos/tp1/props_2017.csv")

# %%
props_2017.head(2)
print("Cantidad registros: "+str(_2017.count()['id']))
# Out:
# Cantidad registros: 421728

# %%
props_2017.dtypes
# Out:
# Unnamed: 0                      int64
# id                             object
# created_on                     object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# description                    object
# title                          object
# dtype: object

# %%
props_2017['created_on'] = pd.to_datetime(props_2017['created_on'],format='%Y-%m-%d')

# %%
props_2017.dtypes
# Out:
# Unnamed: 0                             int64
# id                                    object
# created_on                    datetime64[ns]
# property_type                         object
# place_name                            object
# place_with_parent_names               object
# country_name                          object
# state_name                            object
# geonames_id                          float64
# lat-lon                               object
# lat                                  float64
# lon                                  float64
# price                                float64
# currency                              object
# price_aprox_local_currency           float64
# price_aprox_usd                      float64
# surface_total_in_m2                  float64
# surface_covered_in_m2                float64
# price_usd_per_m2                     float64
# price_per_m2                         float64
# floor                                float64
# rooms                                float64
# expenses                             float64
# description                           object
# title                                 object
# dtype: object

# %%
props_2017 = props_2017[(props_2017['created_on'] >= '2017-01-01') & (props_2017['created_on'] <= '2017-08-31')]

# %%
props_2017.head(2)
# Out:
#        Unnamed: 0                                        id created_on  \
# 24271       35364  e3cb52c36e2210586ddf90fd0443261ea2e5511f 2017-01-01
# 24272       35366  2e61de575b2653733dc55aaed4b08a1e9ae13563 2017-01-01
#
#       property_type     place_name  \
# 24271         house        Quilmes
# 24272     apartment  Villa Urquiza
#
#                                  place_with_parent_names country_name  \
# 24271  |Argentina|Bs.As. G.B.A. Zona Sur|Quilmes|Quil...    Argentina
# 24272          |Argentina|Capital Federal|Villa Urquiza|    Argentina
#
#                    state_name  geonames_id                lat-lon  \
# 24271  Bs.As. G.B.A. Zona Sur    3429651.0  -34.744616,-58.277365
# 24272         Capital Federal    3433775.0  -34.579461,-58.477982
#
#                            ...                        price_aprox_usd  \
# 24271                      ...                                    NaN
# 24272                      ...                               109000.0
#
#        surface_total_in_m2  surface_covered_in_m2 price_usd_per_m2  \
# 24271                  NaN                    NaN              NaN
# 24272                  NaN                   43.0              NaN
#
#        price_per_m2  floor  rooms  expenses  \
# 24271           NaN    NaN    NaN       NaN
# 24272   2534.883721    NaN    1.0       NaN
#
#                                              description  \
# 24271  Corredor Responsable: Martin Veltri - C.M.Q 80...
# 24272  Corredor Responsable: Juan Carlos Treco - CUCI...
#
#                                                title
# 24271                          Casa en Venta Quilmes
# 24272  2 AMBIENTES A ESTRENAR C/BALCÓN VILLA URQUIZA
#
# [2 rows x 25 columns]

# %%
caba = props_2017[props_2017.state_name == 'Capital Federal']
caba.head(2)
# Out:
#        Unnamed: 0                                        id created_on  \
# 24272       35366  2e61de575b2653733dc55aaed4b08a1e9ae13563 2017-01-01
# 24273       35367  5a66865f29a02dbfa89d04ad66e91162c368eb99 2017-01-01
#
#       property_type     place_name                    place_with_parent_names  \
# 24272     apartment  Villa Urquiza  |Argentina|Capital Federal|Villa Urquiza|
# 24273     apartment  Villa Urquiza  |Argentina|Capital Federal|Villa Urquiza|
#
#       country_name       state_name  geonames_id                lat-lon  \
# 24272    Argentina  Capital Federal    3433775.0  -34.579461,-58.477982
# 24273    Argentina  Capital Federal    3433775.0  -34.579461,-58.477982
#
#                              ...                         price_aprox_usd  \
# 24272                        ...                                109000.0
# 24273                        ...                                 89900.0
#
#        surface_total_in_m2  surface_covered_in_m2 price_usd_per_m2  \
# 24272                  NaN                   43.0              NaN
# 24273                  NaN                   38.0              NaN
#
#        price_per_m2  floor  rooms  expenses  \
# 24272   2534.883721    NaN    1.0       NaN
# 24273   2365.789474    NaN    1.0       NaN
#
#                                              description  \
# 24272  Corredor Responsable: Juan Carlos Treco - CUCI...
# 24273  Corredor Responsable: Juan Carlos Treco - CUCI...
#
#                                                   title
# 24272     2 AMBIENTES A ESTRENAR C/BALCÓN VILLA URQUIZA
# 24273  2 Ambientes / Monoambiente con balcon a estrenar
#
# [2 rows x 25 columns]

# %%
caba.groupby('property_type').count()
#Existen 4 tipos de propiedades: PH, apartamento, casa y local
# Out:
#                Unnamed: 0     id  created_on  place_name  \
# property_type
# PH                   7194   7194        7194        7194
# apartment           91484  91484       91484       91484
# house                8235   8235        8235        8235
# store                4252   4252        4252        4252
#
#                place_with_parent_names  country_name  state_name  geonames_id  \
# property_type
# PH                                7194          7194        7194         6927
# apartment                        91484         91484       91484        87445
# house                             8235          8235        8235         8000
# store                             4252          4252        4252         4059
#
#                lat-lon    lat  ...    price_aprox_usd  surface_total_in_m2  \
# property_type                  ...
# PH                6765   6765  ...               6874                 5167
# apartment        76192  76192  ...              83061                73925
# house             6094   6094  ...               7217                 6246
# store             3855   3855  ...               3625                 3284
#
#                surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  \
# property_type
# PH                              6853              4818          6528    695
# apartment                      87440             65734         79561  17712
# house                           7533              5322          6630     22
# store                           3848              2679          3203     34
#
#                rooms  expenses  description  title
# property_type
# PH              5648       635         7194   7194
# apartment      66431     19139        91484  91484
# house           3266        64         8235   8235
# store            274       434         4252   4252
#
# [4 rows x 24 columns]

# %%
#assert caba.groupby(['surface_total_in_m2']).count()['id'] == caba.groupby(['surface_covered_in_m2']).count()['id']
caba.groupby(['surface_covered_in_m2']).count()['id']

#Removemos las propiedades que no tienen metraje
caba = caba[caba.surface_covered_in_m2 != 0]

# %%
caba = caba[caba.surface_total_in_m2 != 0]

# %%
# Nos quedamos con los registros dados de alta sólo durante el año 2017.
caba.created_on.head(2)
caba = caba[(caba.created_on >= '2017-01-01') & (caba.created_on <= '2017-08-31')]

# %%
#Para cada barrio teniendo en cuenta la frecuencia venta ordenamos descendentemente.
#Vamos a asignarle el número de comuna a la que corresponde cada barrio.
def set_comuna(place_name):
    p = str(place_name)
    if p == 'Retiro' or p == 'San Nicolás' or p == 'Puerto Madero' or p == 'San Telmo' or p == 'Monserrat' or p == 'Constitución':
        return 1
    if p == 'Recoleta':
        return 2
    if p == 'San Cristobal' or p == 'Balvanera':
        return 3
    if p == 'Boca' or p == 'Barracas' or p == 'Parque Patricios' or p == 'Pompeya':
        return 4
    if p == 'Almagro' or p == 'Boedo':
        return 5
    if p == 'Caballito':
        return 6
    if p == 'Flores' or p == 'Parque Chacabuco':
        return 7
    if p == 'Villa Soldati' or p == 'Villa Riachuelo' or p == 'Villa Lugano':
        return 8
    if p == 'Parque Avellaneda' or p == 'Liniers' or p == 'Mataderos':
        return 9
    if p == 'Villa Real' or p == 'Monte Castro' or p == 'Versalles' or p == 'Floresta' or p == 'Velez Sarsfield' or p == 'Villa Luro':
        return 10
    if p == 'Villa General Mitre' or p == 'Villa Devoto' or p == 'Villa del Parque' or p == 'Villa Santa Rita':
        return 11
    if p == 'Coghlan' or p == 'Saavedra' or p == 'Villa Urquiza' or p == 'Villa Pueyrredón':
        return 12
    if p == 'Belgrano' or p == 'Nuñez' or p == 'Colegiales':
        return 13
    if p == 'Palermo' or p == 'Palermo Hollywood' or p == 'Palermo Soho' or p == 'Palermo Chico' or p == 'Palermo Viejo':
        return 14
    if p == 'Chacarita' or p == 'Agronomía' or p == 'Villa Crespo' or p =='Villa Ortuzar':
        return 15

# %%
caba['comuna'] = caba['place_name'].apply(set_comuna)

# %%
b_sur = caba[(caba['comuna'] > 0) & (caba['comuna'] <= 9) & (caba['comuna'] != 2) & (caba['comuna'] != 6)]

b_norte = caba[(caba['comuna'] >= 10) | (caba['comuna'] == 2) | (caba['comuna'] == 6)]

# %%
#Analizamos sólo las unidades del tipo departamento
b_sur_apart = b_sur[b_sur.property_type == 'apartment']
rs = b_sur_apart.groupby(['comuna']).mean()['price_usd_per_m2']
rs = rs.reset_index()
rs
# Out:
#    comuna  price_usd_per_m2
# 0     1.0       3218.687220
# 1     3.0       6191.011822
# 2     4.0       2208.959563
# 3     5.0       7541.303304
# 4     7.0       2163.721721
# 5     8.0       1297.409219
# 6     9.0       1968.549403

# %%
b_norte_apart = b_norte[b_norte.property_type == 'apartment']
rn = b_norte_apart.groupby(['comuna']).mean()['price_usd_per_m2']
rn = rn.reset_index()
rn
# Out:
#    comuna  price_usd_per_m2
# 0     2.0       3341.005981
# 1     6.0       2565.632499
# 2    10.0       2009.520323
# 3    11.0       2235.133472
# 4    12.0       2579.914422
# 5    13.0       2991.435569
# 6    14.0       3360.327853
# 7    15.0       2387.329703

# %%
ax = rn.plot.scatter(x='comuna',y='price_usd_per_m2',color='red',label='Norte')
rs.plot.scatter(x='comuna', y='price_usd_per_m2', color='green', label='Sur', ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Se puede ver cómo el promedio de precios de las propiedades del Norte son mayores que el promedio
#correspondiente a la zona Sur

# %%
#Vemos el caso raro de las propiedades correspondientes a la comuna 3 y 5,
#las cuales tienen promedios muy superiores

# %%
print("Cantidad de registros: "+str(b_sur['price_usd_per_m2'].count()))
#b_sur[b_sur['price_usd_per_m2'].isNull()]
#b_sur[b_sur.isnull.any()]
#b_sur.isnull().any()
# Out:
# Cantidad de registros: 24874
